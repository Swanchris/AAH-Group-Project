# %% [markdown]
# # experimental study (parameter tuning)
# #### on randomly generated instances of MS across a range of $n$ and $m$ values in order to select an appropriate value for $k$.

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import random
import re
from itertools import compress
from copy import deepcopy

# %%
class agent:
    def __init__(self): 
        self.initialTime = time.time()
        self.allocation = {} # a dict for tracking  the allocated jobs to machines
        self.workload = np.zeros(m) # np.array of length m, where self.workload[machine] = sum of processing times of jobs assigned to machine
        self.cost = None # cost of current feasible solution
        self.costTrajectory = [] # list of cost of feasible solution found in each step
        self.workload_so_far = []
        self.allocation_so_far = []

        
    # generates a greedy initial feasible solution
    def generateGreedySolution(self):
        for i in range(m):
            self.allocation[i] = [p[i]]
            self.workload[i] += p[i]
        for i in range(m,len(p)):
            worker = np.argmin(self.workload)
            self.allocation[worker].append(p[i])
            self.workload[worker] += p[i]
        self.cost = np.max(self.workload)
        self.costTrajectory.append(self.cost)
        
        
    # switch assigned machine of 'job' to 'toMachine'
    def switchMachine(self,  job, fromMachine, toMachine):
        self.workload[fromMachine] += - job
        self.allocation[fromMachine].remove(job)
        self.workload[toMachine] += job
        self.allocation[toMachine].append(job)
    
    def Swap(self, Big, big_candidate, Small, small_candidate):
        self.switchMachine(Big, big_candidate, small_candidate)
        self.switchMachine(Small, small_candidate, big_candidate)
    
    def greedySearchIteration(self,k):
        ind = np.argsort(self.workload)
        for i in range(k):
            big_candidate = ind[-(i+1)]
            small_candidate = ind[i]
            Big = np.max(self.allocation[big_candidate])
            Small = np.max(list(compress(self.allocation[small_candidate],
                                     [i < Big for i in self.allocation[small_candidate]])))
            self.Swap(Big, big_candidate, Small, small_candidate)
        self.cost = np.max(self.workload)
        self.costTrajectory.append(self.cost)
        self.workload_so_far.append(deepcopy(self.workload))
        self.allocation_so_far.append(deepcopy(self.allocation))
    
    def print_results(self):
        plt.bar(range(m),self.workload)
        plt.show()
#         print('best workload found:', self.workload)
#         print('best allocation found:', self.allocation)
        print('neighbours visited:', self.costTrajectory)
        print('approximation ratio:',  self.cost/np.average(self.workload))
        print('time taken:', time.time() - self.initialTime)
    
    def greedySearch(self,totalTime,k):
        self.generateGreedySolution()
        self.workload_so_far.append(deepcopy(self.workload))
        self.allocation_so_far.append(deepcopy(self.allocation))
        while time.time() - self.initialTime < totalTime - 0.31:
            self.greedySearchIteration(k)
            if self.cost > self.costTrajectory[-2]:
                self.workload = deepcopy(self.workload_so_far[-2])
                self.allocation = deepcopy(self.allocation_so_far[-2])
                self.cost = np.max(self.workload)
                self.costTrajectory.append(self.cost) 
                self.print_results()
                return
            if self.cost == self.costTrajectory[-2]:
                self.print_results()
                return
        print('*****ALLOCATED TIME EXPIRED!*****')
        print('BEST RESULT:')
        self.print_results()
    
    def verifyFeasibleSolution(self):
        # check that each job is assigned to exactly one machine
        assert(sum([len(self.allocation[i]) for i in range(m)]) == len(p))
        # check that there are at most m machines that have jobs assigned to them
        assert(len(self.allocation) <= m)

        # check that the workloads are as indicated in A.workload
        for i in range(m):
            assert(self.workload[i] == sum(self.allocation[i]))

        # check that the maximum of the workloads (i.e. the cost) is as indicated in A.cost
        assert(np.isclose(self.cost, np.max(self.workload)))

# %%
def create_instance(inp, filename):
    txter = open(filename, "w")
    for item in inp:
        txter.write(str(item))
        txter.write('\n')
    txter.close()

# %%
def import_inst(filename):
    '''
    imports a text file instance, converts it to an array and then allocates it to p and m, 
    where p are the jobs and m is the number of machines
    '''
    inst = list(map(int, re.findall('\d+', str([line.rstrip('\n') for line in open(filename)]))))
    global p, m, allowableTime
    p =  inst[2:]
    p.sort()
    p = p[::-1]
    m = inst[1]
    allowableTime = inst[0]

# %%
k = "instance"
for i in range(len(M)):
    print(k + str(i) + ".txt")
# Out:
# instance0.txt
# instance1.txt
# instance2.txt
# instance3.txt
# instance4.txt
# instance5.txt
# instance6.txt
# instance7.txt
# instance8.txt
# instance9.txt

# %%
M = np.random.randint(200,400,10)
P = np.random.randint(2000,40000,10)

# %%
instances = {i:np.append(30,np.append(M[i],1 + np.random.randint(np.random.randint(1000,10000),size = P[i]) )) for i in range(len(M))}

# %%
instances
# Out:
# {0: array([  30,  257,    1, ..., 4593, 4594, 4595]),
#  1: array([  30,  221,   99, ...,  899,  440, 1566]),
#  2: array([  30,  267, 3685, ...,  378, 3941, 1723]),
#  3: array([  30,  215, 5602, ..., 3898,  630,  134]),
#  4: array([  30,  297, 4776, ..., 6190, 3734,   70]),
#  5: array([  30,  265, 5617, ..., 2764, 6527, 1252]),
#  6: array([  30,  231,  277, ..., 2196, 2461, 3097]),
#  7: array([  30,  228, 3332, ..., 3913, 6325, 4415]),
#  8: array([  30,  260, 1704, ..., 7770, 7443, 7338]),
#  9: array([ 30, 317, 823, ..., 590, 558,   6])}

# %%
def set_inst(ind):
    '''
    imports a text file instance, converts it to an array and then allocates it to p and m, 
    where p are the jobs and m is the number of machines
    '''
    inst = ind
    global p, m, allowableTime
    p =  inst[2:]
    p.sort()
    p = p[::-1]
    m = inst[1]
    allowableTime = inst[0]

# %%
np.max(instances[0])
# Out:
# 4595

# %%
set_inst(instances[5])
A = agent()
A.generateGreedySolution()
A.print_results()
print('-----------------------------------------------------')
# Out:
# neighbours visited: [85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.48771023750305176
# -----------------------------------------------------

# %%
for i in range(len(M)):
    for k in range(10):
        print('Number of exchanges (k value):', k)
        print('Number of jobs: ', P[i])
        print('Number of machines: ', M[i])
        set_inst(instances[i])
        A = agent()
        A.greedySearch(allowableTime,k)
        A.verifyFeasibleSolution()
        print('-----------------------------------------------------')
# Out:
# Number of exchanges (k value): 0
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5797834396362305
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67447.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5126523971557617
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67558.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5215702056884766
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67558.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5784976482391357
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67558.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5376007556915283
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67558.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5523757934570312
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67565.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5096373558044434
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67565.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.6253621578216553
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67565.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.5133056640625
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  7498
# Number of machines:  257
# neighbours visited: [67421.0, 67565.0, 67421.0]
# approximation ratio: 1.000778226612497
# time taken: 0.51861572265625
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.6728296279907227
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122500.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.8249070644378662
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122500.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7213470935821533
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122500.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7122564315795898
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122500.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7984542846679688
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122502.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7382509708404541
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122502.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.697317361831665
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122502.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7374343872070312
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122502.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.8024280071258545
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  34221
# Number of machines:  221
# neighbours visited: [122498.0, 122503.0, 122498.0]
# approximation ratio: 1.0000291452905292
# time taken: 0.7242550849914551
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6472339630126953
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6443901062011719
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.7061996459960938
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6664445400238037
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6364800930023193
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.71612548828125
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6539552211761475
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6333601474761963
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253405.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.6598992347717285
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  21127
# Number of machines:  267
# neighbours visited: [253393.0, 253420.0, 253393.0]
# approximation ratio: 1.0000942947855738
# time taken: 0.7599985599517822
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.6729092597961426
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.7422411441802979
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.716768741607666
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.7992103099822998
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.7628445625305176
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.6847443580627441
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.7235572338104248
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.668388843536377
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.656602144241333
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  35702
# Number of machines:  215
# neighbours visited: [574203.0, 574249.0, 574203.0]
# approximation ratio: 1.0000147263920203
# time taken: 0.6571714878082275
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5983572006225586
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62223.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5131258964538574
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62240.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5002744197845459
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62240.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5864324569702148
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62240.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5555276870727539
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62240.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5941934585571289
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62297.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5088932514190674
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62297.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.4999363422393799
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62297.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.5714609622955322
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  5789
# Number of machines:  297
# neighbours visited: [62125.0, 62331.0, 62125.0]
# approximation ratio: 1.0018829363838238
# time taken: 0.4855654239654541
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.457181453704834
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.5774586200714111
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.5146498680114746
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.45179176330566406
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.48012423515319824
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.5964078903198242
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.47572803497314453
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85847.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.45981884002685547
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85874.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.49465346336364746
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  6905
# Number of machines:  265
# neighbours visited: [85732.0, 85903.0, 85732.0]
# approximation ratio: 1.000248224149489
# time taken: 0.5608499050140381
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5275883674621582
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.4945662021636963
# -----------------------------------------------------
# Number of exchanges (k value): 2
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5846424102783203
# -----------------------------------------------------
# Number of exchanges (k value): 3
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.4900190830230713
# -----------------------------------------------------
# Number of exchanges (k value): 4
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121493.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5335853099822998
# -----------------------------------------------------
# Number of exchanges (k value): 5
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121493.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5943636894226074
# -----------------------------------------------------
# Number of exchanges (k value): 6
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121493.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.6162269115447998
# -----------------------------------------------------
# Number of exchanges (k value): 7
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121493.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5516543388366699
# -----------------------------------------------------
# Number of exchanges (k value): 8
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121493.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5271797180175781
# -----------------------------------------------------
# Number of exchanges (k value): 9
# Number of jobs:  17144
# Number of machines:  231
# neighbours visited: [121492.0, 121498.0, 121492.0]
# approximation ratio: 1.0001395187874076
# time taken: 0.5934016704559326
# -----------------------------------------------------
# Number of exchanges (k value): 0
# Number of jobs:  31640
# Number of machines:  228
# neighbours visited: [571424.0, 571424.0]
# approximation ratio: 1.0000218295985224
# time taken: 0.681190013885498
# -----------------------------------------------------
# Number of exchanges (k value): 1
# Number of jobs:  31640
# Number of machines:  228
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-aef11972604d> in <module>
#       6         set_inst(instances[i])
#       7         A = agent()
# ----> 8         A.greedySearch(allowableTime,k)
#       9         A.verifyFeasibleSolution()
#      10         print('-----------------------------------------------------')
#
# <ipython-input-105-d6a86a9b9f3b> in greedySearch(self, totalTime, k)
#      58
#      59     def greedySearch(self,totalTime,k):
# ---> 60         self.generateGreedySolution()
#      61         self.workload_so_far.append(deepcopy(self.workload))
#      62         self.allocation_so_far.append(deepcopy(self.allocation))
#
# <ipython-input-105-d6a86a9b9f3b> in generateGreedySolution(self)
#      16             self.workload[i] += p[i]
#      17         for i in range(m,len(p)):
# ---> 18             worker = np.argmin(self.workload)
#      19             self.allocation[worker].append(p[i])
#      20             self.workload[worker] += p[i]
#
# <__array_function__ internals> in argmin(*args, **kwargs)
#
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in argmin(a, axis, out)
#    1220
#    1221     """
# -> 1222     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#    1223
#    1224
#
# C:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:

# %%
p
# Out:
# array([4595, 4594, 4593, ...,    5,    2,    1])
