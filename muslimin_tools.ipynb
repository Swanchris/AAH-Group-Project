# %%
import numpy as np

# %%
jobs = np.array([[1995,856,564,260], [1982,800,520,204], [1920,878,587,290]])

# %%
jobs
# Out:
# array([[1995,  856,  564,  260],
#        [1982,  800,  520,  204],
#        [1920,  878,  587,  290]])

# %%
machines = np.array([1,2,3])

# %%
machines
# Out:
# array([1, 2, 3])

# %%
jobs[0]
# Out:
# array([1995,  856,  564,  260])

# %%
jobs[0] = np.append(jobs[0],np.sum(jobs[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a5adda640ce1> in <module>
# ----> 1 jobs[0] = np.append(jobs[0],np.sum(jobs[0]))
#
# ValueError: could not broadcast input array from shape (5) into shape (4)

# %%
len(jobs[0])
# Out:
# 4

# %%
temp = []
for i in range(len(jobs)):
   temp = np.array(np.append(jobs[i],np.sum(jobs[i])))

# %%
temp
# Out:
# array([0.])

# %%
times = np.array([])

# %%
times
# Out:
# array([], dtype=float64)

# %%
for i in range(len(jobs)):
    times = np.append(times,np.sum(jobs[i]))

# %%
times
# Out:
# array([3675., 3506., 3675.])

# %%
np.max(times)
# Out:
# 3675.0

# %%
np.argmax(times)
# Out:
# 0

# %%
times[0]
# Out:
# 3675.0

# %%
jobs[0]
# Out:
# array([1995,  856,  564,  260])

# %%
costBeta = self.workload[np.argmax(self.workload)] # find max workload across machines, faster than np.max(self.workload) 
        # if new feasible solution is worse then go back, otherwise stay
        if costBeta > costAlpha:
            for (job, machine) in zip(jobs, initialMachines):
                self.switchMachine(job, machine)
            self.costTrajectory.append(costAlpha)
        else:
            self.cost = costBeta
            self.costTrajectory.append(costBeta)

# %%
jobs
# Out:
# array([[1995,  856,  564,  260],
#        [1982,  800,  520,  204],
#        [1920,  878,  587,  290]])

# %%
temp = []
for i in range(len(jobs)):
    for j in range(len(jobs[i])):
        temp.append(jobs[i][j])

# %%
temp
# Out:
# [1995, 856, 564, 260, 1982, 800, 520, 204, 1920, 878, 587, 290]

# %%
costAlpha = 0

# %%
costBeta = np.argmax(times)

# %%
np.argmin(times)
# Out:
# 1

# %%
times[costBeta]
# Out:
# 3675.0

# %%
if costBeta > costAlpha:
    for (job, machine) in zip(jobs, initialMachines):
        self.switchMachine(job, machine)
        self.costTrajectory.append(costAlpha)
    else:
        self.cost = costBeta
        self.costTrajectory.append(costBeta)

# %%
for (job, machine) in zip(jobs, machines):
    print(job,machine)
# Out:
# [1995  856  564  260] 1
# [1982  800  520  204] 2
# [1920  878  587  290] 3

# %%
times
# Out:
# array([3675., 3506., 3675.])

# %%
times[costBeta] - jobs[np.argmax(times)][np.argmax(jobs[np.argmax(times)])] + jobs[np.argmax(times)+1][np.argmax(jobs[np.argmax(times)])]
# Out:
# 3662.0

# %%
print(jobs[np.argmax(times)][np.argmax(jobs[np.argmax(times)])])
print(jobs[np.argmax(times)+1][np.argmax(jobs[np.argmax(times)])])
# Out:
# 1995
# 1982

# %% [markdown]
# workload <- times
# p <- jobs
# machine <- machine

# %%
def switchMachine(self, job, toMachine):
    self.workload[self.machine[job]] = machine[job] -p[job]
    self.machine[job] = toMachine
    self.workload[toMachine] += p[job]

# %%
A = [1,2,3]
B = [4,5,6]

for (i,j) in zip(A,B):
    print(i,j)
# Out:
# 1 4
# 2 5
# 3 6

# %%
allowableTime = 1
m = 4
p = [3, 2, 4, 1, 3, 3, 6, 2, 5, 4, 6]

# %%
# work on putting p into 4 machines
# get python to do the swaps
# try to find an optimal solution

# %%
workload = np.zeros(m)

# %%
workload
# Out:
# array([0., 0., 0., 0.])

# %%
# write a loop (ie for i in range(len(p)) ) to put the jobs in p into workloads
# first, manually swap the element to move toward optimality - workload[j] - p[k],  workload[i] + p[k]

# %%
workload[0] = p[0]
